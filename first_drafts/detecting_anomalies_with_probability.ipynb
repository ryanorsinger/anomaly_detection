# %%
from __future__ import division
import itertools
import warnings
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import math
from sklearn import metrics
from random import randint
from matplotlib import style
import seaborn as sns
# %matplotlib inline
warnings.filterwarnings("ignore")

colnames = ['ip', 'timestamp', 'request_method', 'status', 'size',
          'destination', 'request_agent']
df = pd.read_csv('http://python.zach.lol/access.log',          
                 engine='python',
                 header=None,
                 index_col=False,
                 names=colnames,
                 sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                 na_values='"-"',
                 usecols=[0, 3, 4, 5, 6, 7, 8]
)

# %%
print(df.describe())
df.columns
# Out:
#              status           size
# count  13974.000000   13974.000000
# mean     200.342350  449900.797338
# std       10.112012  160742.535606
# min      200.000000       0.000000
# 25%      200.000000  500637.000000
# 50%      200.000000  510138.000000
# 75%      200.000000  511291.000000
# max      499.000000  513736.000000
# Index(['ip', 'timestamp', 'request_method', 'status', 'size', 'destination',
#        'request_agent'],
#       dtype='object')

# %%
df.head()
# Out:
#              ip                     timestamp  \
# 0  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 1  97.105.19.58  [16/Apr/2019:19:34:42 +0000]
# 2  97.105.19.58  [16/Apr/2019:19:34:44 +0000]
# 3  97.105.19.58  [16/Apr/2019:19:34:46 +0000]
# 4  97.105.19.58  [16/Apr/2019:19:34:48 +0000]
#
#                          request_method  status    size destination  \
# 0  "GET /api/v1/sales?page=81 HTTP/1.1"     200  512495         NaN
# 1          "GET /api/v1/items HTTP/1.1"     200    3561         NaN
# 2  "GET /api/v1/sales?page=82 HTTP/1.1"     200  510103         NaN
# 3  "GET /api/v1/sales?page=83 HTTP/1.1"     200  510003         NaN
# 4  "GET /api/v1/sales?page=84 HTTP/1.1"     200  511963         NaN
#
#               request_agent
# 0  "python-requests/2.21.0"
# 1  "python-requests/2.21.0"
# 2  "python-requests/2.21.0"
# 3  "python-requests/2.21.0"
# 4  "python-requests/2.21.0"

# %%
df.request_method.value_counts()
# Out:
# "GET /api/v1/sales?page=2 HTTP/1.1"                       709
# "GET /api/v1/items HTTP/1.1"                              464
# "GET /api/v1/items?page=2 HTTP/1.1"                       291
# "GET /api/v1/items?page=3 HTTP/1.1"                       219
# "GET /api/v1/stores HTTP/1.1"                             162
# "GET /api/v1/sales HTTP/1.1"                              152
# "GET / HTTP/1.1"                                          107
# "GET /documentation HTTP/1.1"                             100
# "GET /api/v1/sales?page=3 HTTP/1.1"                        91
# "GET /api/v1/items?page=1 HTTP/1.1"                        88
# "GET /api/v1/sales?page=4 HTTP/1.1"                        83
# "GET /api/v1/sales?page=5 HTTP/1.1"                        83
# "GET /api/v1/sales?page=6 HTTP/1.1"                        78
# "GET /api/v1/sales?page=8 HTTP/1.1"                        76
# "GET /api/v1/sales?page=7 HTTP/1.1"                        76
# "GET /api/v1/sales?page=10 HTTP/1.1"                       75
# "GET /api/v1/sales?page=9 HTTP/1.1"                        75
# "GET /api/v1/sales?page=11 HTTP/1.1"                       74
# "GET /api/v1/sales?page=18 HTTP/1.1"                       74
# "GET /api/v1/sales?page=12 HTTP/1.1"                       74
# "GET /api/v1/sales?page=19 HTTP/1.1"                       73
# "GET /api/v1/sales?page=17 HTTP/1.1"                       73
# "GET /api/v1/sales?page=16 HTTP/1.1"                       73
# "GET /api/v1/sales?page=14 HTTP/1.1"                       73
# "GET /api/v1/sales?page=15 HTTP/1.1"                       73
# "GET /api/v1/sales?page=20 HTTP/1.1"                       73
# "GET /api/v1/sales?page=13 HTTP/1.1"                       73
# "GET /api/v1/sales?page=21 HTTP/1.1"                       73
# "GET /api/v1/sales?page=22 HTTP/1.1"                       72
# "GET /api/v1/sales?page=23 HTTP/1.1"                       71
#                                                          ...
# "GET /api/v1/sales?page=175 HTTP/1.1"                      59
# "GET /api/v1/sales?page=143 HTTP/1.1"                      59
# "GET /api/v1/sales?page=1 HTTP/1.1"                        57
# "GET /api/v1/stores?page=1 HTTP/1.1"                       56
# "GET /favicon.ico HTTP/1.1"                                26
# "GET /api/v1//api/v1/items?page=2 HTTP/1.1"                10
# "GET /api/v1/items/api/v1/items?page=2 HTTP/1.1"            6
# "GET /api/v1/items/next_page HTTP/1.1"                      5
# "GET /api/v1/stores?page=3 HTTP/1.1"                        4
# "GET /api/v1/ HTTP/1.1"                                     4
# "GET /api/v1/itemsitems HTTP/1.1"                           3
# "GET /api/v1/sales/?page=2 HTTP/1.1"                        3
# "GET /api/v1/store HTTP/1.1"                                3
# "GET /api/v1/stores?page=0 HTTP/1.1"                        2
# "GET /api/v1/stores?page=183 HTTP/1.1"                      2
# "GET /api/v1items HTTP/1.1"                                 2
# "GET /api/v1/items&page=0 HTTP/1.1"                         1
# "GET /api/v1/helloclass! HTTP/1.1"                          1
# "GET /api/v1/I_DIDNT_DO_IT!!!! HTTP/1.1"                    1
# "GET /api/v1//api/v1/items/next_page HTTP/1.1"              1
# "GET /api/v1//api/v1/items HTTP/1.1"                        1
# "GET /api/v1/items/api/v1/items?page=3 HTTP/1.1"            1
# "GET /api/v1/stores?page=999 HTTP/1.1"                      1
# "GET /api/v1/items?page=99999999999999999998 HTTP/1.1"      1
# "GET /api/v1/items?page=4 HTTP/1.1"                         1
# "GET /api/v1/stores?page=666 HTTP/1.1"                      1
# "GET /api/v1/items?page=0 HTTP/1.1"                         1
# "GET /api/v1 HTTP/1.1"                                      1
# "GET /api/V1/HiZach! HTTP/1.1"                              1
# "GET /api/v1/stores?page=2 HTTP/1.1"                        1
# Name: request_method, Length: 218, dtype: int64

# %%
sorted_size = df["size"].sort_values(ascending=False)
sorted_size.value_counts().sort_values(ascending=False)
# Out:
# 494819    705
# 3561      548
# 3659      291
# 1328      229
# 1787      219
# 493905    209
# 510134    183
# 510142    179
# 510139    129
# 510144    126
# 511577    125
# 510138    123
# 510120    123
# 510540    120
# 510135    120
# 511963    120
# 42        107
# 348       100
# 499787     90
# 501929     83
# 500461     83
# 500163     78
# 500637     76
# 500125     75
# 500113     75
# 501714     75
# 501935     74
# 499982     73
# 499779     73
# 499050     73
#          ...
# 510054     59
# 510217     59
# 513236     59
# 510019     59
# 509800     59
# 511176     59
# 510337     59
# 512099     59
# 510149     59
# 511624     59
# 510143     59
# 510124     59
# 510023     59
# 510316     59
# 510788     59
# 511340     59
# 511628     59
# 511956     59
# 510039     59
# 510052     59
# 510111     59
# 0          16
# 48          3
# 130921      3
# 327529      1
# 343913      1
# 278377      1
# 409449      1
# 360297      1
# 126         1
# Name: size, Length: 187, dtype: int64
